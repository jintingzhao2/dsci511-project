# %% [markdown]
# <a href="https://colab.research.google.com/github/jintingzhao2/dsci511-project/blob/main/Phase_2_Report_Group_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CMS Hospital Data

# %%
from concurrent.futures import ThreadPoolExecutor

import requests
import pandas as pd

# %% [markdown]
# # Constants

# %%
CMS_BASE_URL = "https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0"
PAGE_SIZE = 1500

CENSUS_API_KEY = "bfdde094ae5a6a5a9ba319a6c06a967d511dbb3f"
CENSUS_BASE_URL = "https://api.census.gov/data/2023/acs/acs5/subject"

GEOCODING_BASE_URL = "https://geocoding.geo.census.gov/geocoder/geographies/address"

# %% [markdown]
# # CMS Hosptial Data

# %%
def fetch_page(offset: int) -> pd.DataFrame:
    """Fetch one page of data from CMS API."""
    url = (
        f"{CMS_BASE_URL}?offset={offset}&"
         "count=true&"
         "results=true&"
         "schema=true&"
         "keys=true&"
         "format=csv&"
         "rowIds=false"
    )
    print(f"Calling {url}")
    return pd.read_csv(url)

# %%
def get_total_number_of_rows() -> int:
  initial_url = (
      f"{CMS_BASE_URL}?offset=0&count=true&results=true&schema=false&keys=true"
      "&format=json&rowIds=false"
  )
  response = requests.get(initial_url)
  response.raise_for_status()
  data = response.json()

  total_count = data["count"]
  print(f"Total number of rows: {total_count}")
  return total_count

total_number_of_rows_for_cms_data = get_total_number_of_rows()
# Out:
# Total number of rows: 172476

# %%
offsets = list(range(0, total_number_of_rows_for_cms_data, PAGE_SIZE))
print(f"Fetching {len(offsets)} pages concurrently...")
# Out:
# Fetching 115 pages concurrently...

# %%
# cms_df = pd.concat([fetch_page(offset=offset) for offset in offsets])

def fetch_all(offsets, max_workers=10):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        results = list(executor.map(fetch_page, offsets))
    return pd.concat(results, ignore_index=True)

cms_df = fetch_all(offsets)
# Out:
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=0&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=1500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=3000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=4500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=6000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=7500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=9000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=10500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=12000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=13500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=15000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=16500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=18000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=19500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=21000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=22500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=24000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=25500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=27000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=28500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=30000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=31500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=33000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=34500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=36000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=37500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=39000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=40500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=42000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=43500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=45000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=46500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=48000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=49500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=51000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=52500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=54000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=55500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=57000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=58500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=60000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=61500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=63000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=64500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=66000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=67500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=69000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=70500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=72000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=73500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=75000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=76500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=78000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=79500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=81000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=82500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=84000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=85500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=87000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=88500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=90000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=91500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=93000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=94500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=96000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=97500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=99000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=100500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=102000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=103500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=105000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=106500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=108000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=109500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=111000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=112500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=114000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=115500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=117000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=118500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=120000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=121500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=123000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=124500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=falseCalling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=126000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
#
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=127500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=129000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=130500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=132000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=133500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=135000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=136500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=138000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=139500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=141000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=142500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=144000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=145500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=147000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=148500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=150000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=151500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=153000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=154500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=156000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=157500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=159000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=160500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=162000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=163500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=165000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=166500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=168000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=169500&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false
# Calling https://data.cms.gov/provider-data/api/1/datastore/query/77hc-ibv8/0?offset=171000&count=true&results=true&schema=true&keys=true&format=csv&rowIds=false

# %%
print(cms_df.shape)
cms_df.to_csv("cms-data.csv", index=False)
cms_df.head()
# Out:
# (172476, 15)
#   Facility ID                    Facility Name                 Address  \
# 0       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number       Measure ID  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701    HAI_1_CILOWER
# 1    DOTHAN    AL     36301       HOUSTON   (334) 793-8701    HAI_1_CIUPPER
# 2    DOTHAN    AL     36301       HOUSTON   (334) 793-8701       HAI_1_DOPC
# 3    DOTHAN    AL     36301       HOUSTON   (334) 793-8701  HAI_1_ELIGCASES
# 4    DOTHAN    AL     36301       HOUSTON   (334) 793-8701  HAI_1_NUMERATOR
#
#                                         Measure Name  \
# 0  Central Line Associated Bloodstream Infection ...
# 1  Central Line Associated Bloodstream Infection ...
# 2  Central Line Associated Bloodstream Infection:...
# 3  Central Line Associated Bloodstream Infection ...
# 4  Central Line Associated Bloodstream Infection ...
#
#                    Compared to National  Score Footnote  Start Date  \
# 0  No Different than National Benchmark  0.194      NaN  01/01/2024
# 1  No Different than National Benchmark  1.174      NaN  01/01/2024
# 2  No Different than National Benchmark   8935      NaN  01/01/2024
# 3  No Different than National Benchmark  9.440      NaN  01/01/2024
# 4  No Different than National Benchmark      5      NaN  01/01/2024
#
#      End Date
# 0  12/31/2024
# 1  12/31/2024
# 2  12/31/2024
# 3  12/31/2024
# 4  12/31/2024

# %%
def filter_for_pa(df: pd.DataFrame) -> pd.DataFrame:
  return df.query("State == 'PA'")

def pivot_by_measure_name(df: pd.DataFrame) -> pd.DataFrame:
  return (
      df.pivot(
        index=[
            "Facility ID", "Facility Name", "Address", "City/Town", "State",
            "ZIP Code", "County/Parish", "Telephone Number", "Start Date",
            "End Date"
        ],
        columns="Measure Name",
        values="Score",
    ).reset_index()
  )


def rename_cms_columns(df: pd.DataFrame) -> pd.DataFrame:
  return df.rename(columns={
    "Facility ID": "facility_id",
    "Facility Name": "facility_name",
    "Address": "address",
    "City/Town": "city",
    "State": "state",
    "ZIP Code": "zip_code",
    "County/Parish": "county",
    "Telephone Number": "telephone_number",
    "Start Date": "start_date",
    "End Date": "end_date",

    # CAUTI (Catheter Associated UTI)
    "Catheter Associated Urinary Tract Infections (ICU + select Wards)": "cauti_sir",
    "Catheter Associated Urinary Tract Infections (ICU + select Wards): Lower Confidence Limit": "cauti_lcl",
    "Catheter Associated Urinary Tract Infections (ICU + select Wards): Number of Urinary Catheter Days": "cauti_catheter_days",
    "Catheter Associated Urinary Tract Infections (ICU + select Wards): Observed Cases": "cauti_observed",
    "Catheter Associated Urinary Tract Infections (ICU + select Wards): Predicted Cases": "cauti_predicted",
    "Catheter Associated Urinary Tract Infections (ICU + select Wards): Upper Confidence Limit": "cauti_ucl",

    # CLABSI
    "Central Line Associated Bloodstream Infection (ICU + select Wards)": "clabsi_sir",
    "Central Line Associated Bloodstream Infection (ICU + select Wards): Lower Confidence Limit": "clabsi_lcl",
    "Central Line Associated Bloodstream Infection (ICU + select Wards): Observed Cases": "clabsi_observed",
    "Central Line Associated Bloodstream Infection (ICU + select Wards): Predicted Cases": "clabsi_predicted",
    "Central Line Associated Bloodstream Infection (ICU + select Wards): Upper Confidence Limit": "clabsi_ucl",
    "Central Line Associated Bloodstream Infection: Number of Device Days": "clabsi_device_days",

    # C.Diff
    "Clostridium Difficile (C.Diff)": "cdiff_sir",
    "Clostridium Difficile (C.Diff): Lower Confidence Limit": "cdiff_lcl",
    "Clostridium Difficile (C.Diff): Observed Cases": "cdiff_observed",
    "Clostridium Difficile (C.Diff): Patient Days": "cdiff_patient_days",
    "Clostridium Difficile (C.Diff): Predicted Cases": "cdiff_predicted",
    "Clostridium Difficile (C.Diff): Upper Confidence Limit": "cdiff_ucl",

    # MRSA Bacteremia
    "MRSA Bacteremia": "mrsa_sir",
    "MRSA Bacteremia: Lower Confidence Limit": "mrsa_lcl",
    "MRSA Bacteremia: Observed Cases": "mrsa_observed",
    "MRSA Bacteremia: Patient Days": "mrsa_patient_days",
    "MRSA Bacteremia: Predicted Cases": "mrsa_predicted",
    "MRSA Bacteremia: Upper Confidence Limit": "mrsa_ucl",

    # SSI – Abdominal Hysterectomy
    "SSI - Abdominal Hysterectomy": "ssi_hyst_sir",
    "SSI - Abdominal Hysterectomy: Lower Confidence Limit": "ssi_hyst_lcl",
    "SSI - Abdominal Hysterectomy: Number of Procedures": "ssi_hyst_procedures",
    "SSI - Abdominal Hysterectomy: Observed Cases": "ssi_hyst_observed",
    "SSI - Abdominal Hysterectomy: Predicted Cases": "ssi_hyst_predicted",
    "SSI - Abdominal Hysterectomy: Upper Confidence Limit": "ssi_hyst_ucl",

    # SSI – Colon Surgery
    "SSI - Colon Surgery": "ssi_colon_sir",
    "SSI - Colon Surgery: Lower Confidence Limit": "ssi_colon_lcl",
    "SSI - Colon Surgery: Number of Procedures": "ssi_colon_procedures",
    "SSI - Colon Surgery: Observed Cases": "ssi_colon_observed",
    "SSI - Colon Surgery: Predicted Cases": "ssi_colon_predicted",
    "SSI - Colon Surgery: Upper Confidence Limit": "ssi_colon_ucl",
})

cms_transformed_df = (
    cms_df.pipe(filter_for_pa)
    .pipe(pivot_by_measure_name)
    .pipe(rename_cms_columns)
    .dropna()
)

# %%
cms_transformed_df
# Out:
# Measure Name facility_id                       facility_name  \
# 1                 390203                 DOYLESTOWN HOSPITAL
# 2                 390204                   NAZARETH HOSPITAL
# 5                 390219      EXCELA HEALTH LATROBE HOSPITAL
# 7                 390223    PENN PRESBYTERIAN MEDICAL CENTER
# 9                 390226               PENNSYLVANIA HOSPITAL
# ..                   ...                                 ...
# 155               390180       CROZER CHESTER MEDICAL CENTER
# 156               390183  ST LUKE'S MINERS MEMORIAL HOSPITAL
# 157               390184        PENN HIGHLANDS CONNELLSVILLE
# 159               390195         MAIN LINE HOSPITAL LANKENAU
# 161               390199          PUNXSUTAWNEY AREA HOSPITAL
#
# Measure Name                       address           city state  zip_code  \
# 1                        595 WEST STATE ST     DOYLESTOWN    PA     18901
# 2                           2601 HOLME AVE   PHILADELPHIA    PA     19152
# 5                           ONE MELLON WAY        LATROBE    PA     15650
# 7                     51 NORTH 39TH STREET   PHILADELPHIA    PA     19104
# 9                        800 SPRUCE STREET   PHILADELPHIA    PA     19107
# ..                                     ...            ...   ...       ...
# 155           ONE MEDICAL CENTER BOULEVARD         UPLAND    PA     19013
# 156                    360 W RUDDLE STREET       COALDALE    PA     18218
# 157                 401 EAST MURPHY AVENUE  CONNELLSVILLE    PA     15425
# 159                      100 LANCASTER AVE      WYNNEWOOD    PA     19096
# 161                     81 HILLCREST DRIVE   PUNXSUTAWNEY    PA     15767
#
# Measure Name        county telephone_number  start_date    end_date  ...  \
# 1                    BUCKS   (215) 345-2200  01/01/2024  12/31/2024  ...
# 2             PHILADELPHIA   (215) 335-6000  01/01/2024  12/31/2024  ...
# 5             WESTMORELAND   (724) 832-4000  01/01/2024  12/31/2024  ...
# 7             PHILADELPHIA   (215) 662-8000  01/01/2024  12/31/2024  ...
# 9             PHILADELPHIA   (215) 829-3000  01/01/2024  12/31/2024  ...
# ..                     ...              ...         ...         ...  ...
# 155               DELAWARE   (610) 447-2000  01/01/2024  12/31/2024  ...
# 156             SCHUYLKILL   (570) 645-2131  01/01/2024  12/31/2024  ...
# 157                FAYETTE   (724) 628-1500  01/01/2024  12/31/2024  ...
# 159             MONTGOMERY   (610) 645-2000  01/01/2024  12/31/2024  ...
# 161              JEFFERSON   (814) 938-1800  01/01/2024  12/31/2024  ...
#
# Measure Name ssi_hyst_procedures ssi_hyst_observed ssi_hyst_predicted  \
# 1                             13                 0              0.086
# 2                              1                 0              0.013
# 5                              2                 0              0.014
# 7                            114                 1              0.912
# 9                            389                 3              3.134
# ..                           ...               ...                ...
# 155                           30                 0              0.273
# 156                Not Available     Not Available      Not Available
# 157                Not Available     Not Available      Not Available
# 159                          212                 1              1.720
# 161                            3                 0              0.025
#
# Measure Name   ssi_hyst_ucl  ssi_colon_sir  ssi_colon_lcl  \
# 1             Not Available          0.906          0.288
# 2             Not Available  Not Available  Not Available
# 5             Not Available          1.623          0.516
# 7             Not Available          0.911          0.399
# 9                     2.605          1.033          0.379
# ..                      ...            ...            ...
# 155           Not Available          3.257          1.035
# 156           Not Available  Not Available  Not Available
# 157           Not Available  Not Available  Not Available
# 159                   2.867          0.613          0.249
# 161           Not Available  Not Available  Not Available
#
# Measure Name ssi_colon_procedures ssi_colon_observed ssi_colon_predicted  \
# 1                             183                  4               4.413
# 2                              25                  0               0.689
# 5                              95                  4               2.464
# 7                             250                  7               7.682
# 9                             183                  5               4.838
# ..                            ...                ...                 ...
# 155                            43                  4               1.228
# 156                            17                  0               0.465
# 157                 Not Available      Not Available       Not Available
# 159                           380                  6               9.781
# 161                            12                  0               0.287
#
# Measure Name  ssi_colon_ucl
# 1                     2.186
# 2             Not Available
# 5                     3.916
# 7                     1.802
# 9                     2.291
# ..                      ...
# 155                   7.857
# 156           Not Available
# 157           Not Available
# 159                   1.276
# 161           Not Available
#
# [100 rows x 46 columns]

# %% [markdown]
# # Census Data

# %%
def get_census_data() -> pd.DataFrame:
  # Defining query parameters
  params = {
      "get": "NAME,S1901_C01_012E,S1701_C03_001E",  # Median Income, Poverty %
      "for": "tract:*",                             # All tracts
      "in": "state:42 county:*",                    # PA = FIPS 42, all counties in PA
      "key": CENSUS_API_KEY
  }

  # Making requests
  response = requests.get(CENSUS_BASE_URL, params=params)
  data = response.json()

  # Converting to DataFrame
  return pd.DataFrame(data[1:], columns=data[0])

census_df = get_census_data()

# %%
census_df = (
    census_df.rename(columns={
      "S1901_C01_012E": "median_income",
      "S1701_C03_001E": "poverty_percentage",
  }).drop(columns=["NAME", "state", "county"])
)
census_df
# Out:
#      median_income poverty_percentage   tract
# 0            82716                5.6  030101
# 1           111227                4.0  030103
# 2            66848                4.1  030104
# 3            72431                9.6  030200
# 4            84643                8.0  030300
# ...            ...                ...     ...
# 3441        109438                3.4  023902
# 3442         81148                8.9  023903
# 3443        135350                0.8  023904
# 3444         86060                5.1  024001
# 3445        110602                5.5  024002
#
# [3446 rows x 3 columns]

# %% [markdown]
# # Geocoding Data

# %%
hospital_addresses = list(
    cms_transformed_df[["address", "city", "state"]].drop_duplicates()
    .itertuples(index=False, name=None)
)

# %%
len(hospital_addresses)
# Out:
# 100

# %%
def create_geocoding_url(street: str, city: str, state: str) -> str:
  print(street, city, state)
  return f"{GEOCODING_BASE_URL}?street={street}&city={city}&state={state}&benchmark=Public_AR_Current&vintage=Current_Current&layers=10&format=json"

# %%
with ThreadPoolExecutor(max_workers=10) as executor:
  responses = list(executor.map(
      lambda hospital_address: requests.get(
          create_geocoding_url(street=hospital_address[0], city=hospital_address[1], state=hospital_address[2])
      ), hospital_addresses
  ))
# Out:
# 595 WEST STATE ST DOYLESTOWN PA
# 2601 HOLME AVE PHILADELPHIA PA
# ONE MELLON WAY LATROBE PA
# 51 NORTH 39TH STREET PHILADELPHIA PA
# 800 SPRUCE STREET PHILADELPHIA PA
# 1000 BOWER HILL ROAD PITTSBURGH PA
# 1200 OLD YORK ROAD ABINGTON PA
# 500 UNIVERSITY DRIVE HERSHEY PA
# 1000 EAST MOUNTAIN BOULEVARD WILKES BARRE PA
# 1033 WEST GERMANTOWN PIKE NORRISTOWN PA
# 5800 RIDGE AVE PHILADELPHIA PA
# 239 EDGEWOOD DRIVE EXTENSION TRANSFER PA
# 2752 CENTURY BOULEVARD WYOMISSING PA
# 3300 TILLMAN DRIVE BENSALEM PA
# 100 TRICH DRIVE WASHINGTON PA
# 454 ENTERPRISE DRIVE ROYERSFORD PA
# 1861 POWDER MILL RD YORK PA
# 1872 ST LUKE'S BLVD EASTON PA
# 55 MONUMENT ROAD YORK PA
# 559 WEST GERMANTOWN PIKE EAST NORRITON PA
# 840 WALNUT STREET PHILADELPHIA PA
# 100 PARAMOUNT BOULEVARD ORWIGSBURG PA
# 6321 ROUTE 30 GREENSBURG PA
# 255 ROUTE 220 HIGHWAY MUNCY PA
# 330 MAIN STREET DICKSON CITY PA
# 3369 STATE ROUTE 100 MACUNGIE PA
# 1020 THOMPSON STREET JERSEY SHORE PA
# 200 HOSPITAL DRIVE MEYERSDALE PA
# 214 PEACH ORCHARD ROAD MCCONNELLSBURG PA
# 1001 PINE STREET RENOVO PA
# 100 HOSPITAL DRIVE MONTROSE PA
# 187 HOSPITAL DRIVE TYRONE PA
# 965 SHAMROCK LANE CORRY PA
# 2872 TURNPIKE STREET SUSQUEHANNA PA
# 32-36 CENTRAL AVENUE WELLSBORO PA
# 290 HAIDA AVENUE HASTINGS PA
# 4372 ROUTE 6 KANE PA
# ONE CHILDREN'S HOSPITAL DRIVE PITTSBURGH PA
# 3401 CIVIC CENTER BLVD PHILADELPHIA PA
# 5324 PENN AVENUE PITTSBURGH PA
# 160 EAST ERIE AVE PHILADELPHIA PA
# 3551 N BROAD STREET PHILADELPHIA PA
# 1822 MULBERRY STREET SCRANTON PA
# 1500 FIFTH AVENUE MC KEESPORT PA
# 100 NORTH ACADEMY AVENUE DANVILLE PA
# ONE HOSPITAL DRIVE LEWISBURG PA
# 1211 WILMINGTON AVENUE NEW CASTLE PA
# 2907 PLEASANT VALLEY BOULEVARD ALTOONA PA
# 136 W DIAMOND STREET PHILADELPHIA PA
# 8835 GERMANTOWN AVENUE PHILADELPHIA PA
# 3401 NORTH BROAD STREET PHILADELPHIA PA
# 1400 LOCUST STREET PITTSBURGH PA
# 1000 DUTCH RIDGE ROAD BEAVER PA
# 720 BLACKBURN ROAD SEWICKLEY PA
# 225 SOUTH CENTER AVENUE SOMERSET PA
# 420 S 5TH AVENUE WEST READING PA
# 1001 SOUTH GEORGE STREET YORK PA
# 400 HIGHLAND AVENUE LEWISTOWN PA
# 801 OSTRUM STREET BETHLEHEM PA
# 1400 BLACK HORSE HILL ROAD COATESVILLE PA
# 320 EAST NORTH AVENUE PITTSBURGH PA
# 1225 WARM SPRINGS AVE HUNTINGDON PA
# 135 EAST 38TH STREET ERIE PA
# 409 SOUTH SECOND STREET HARRISBURG PA
# 1700 SOUTH LINCOLN AVENUE LEBANON PA
# 501 BATH ROAD BRISTOL PA
# 620 HOWARD AVENUE ALTOONA PA
# ONE GUTHRIE SQUARE SAYRE PA
# 100 HOSPITAL AVENUE DUBOIS PA
# 4800 FRIENDSHIP AVENUE PITTSBURGH PA
# 555 NORTH DUKE STREET LANCASTER PA
# 1701 INNOVATION DRIVE YORK PA
# 815 FREEPORT ROAD PITTSBURGH PA
# 9100 BABCOCK BOULEVARD PITTSBURGH PA
# 34TH & SPRUCE STS PHILADELPHIA PA
# 600 SOMERSET AVENUE WINDBER PA
# 300 HALKET STREET PITTSBURGH PA
# 10800 KNIGHTS ROAD PHILADELPHIA PA
# 10455 LINCOLN HIGHWAY EVERETT PA
# 140 NUTT ROAD PHOENIXVILLE PA
# UNIVERSITY DRIVE PITTSBURGH PA
# 1200 SOUTH CEDAR CREST BOULEVARD ALLENTOWN PA
# 575 NORTH RIVER STREET WILKES-BARRE PA
# 501 EAST MAIN ST WAYNESBORO PA
# 532 WEST PITTSBURGH STREET GREENSBURG PA
# 2 CRESCENT PARK WEST WARREN PA
# 350 BONAR AVENUE WAYNESBURG PA
# 255 WEST LANCASTER AVENUE PAOLI PA
# 1500 LANSDOWNE  AVE DARBY PA
# 100 MEDICAL BOULEVARD CANONSBURG PA
# 200 LOTHROP STREET PITTSBURGH PA
# ONE HOSPITAL WAY BUTLER PA
# 835 HOSPITAL ROAD INDIANA PA
# 110 NORTH MAIN STREET GREENVILLE PA
# 701 EAST MARSHALL STREET WEST CHESTER PA
# ONE MEDICAL CENTER BOULEVARD UPLAND PA
# 360 W RUDDLE STREET COALDALE PA
# 401 EAST MURPHY AVENUE CONNELLSVILLE PA
# 100 LANCASTER AVE WYNNEWOOD PA
# 81 HILLCREST DRIVE PUNXSUTAWNEY PA

# %%
pa_geodata_data = [response.json() for response in responses]

# %%
pa_geodata = []
for data in pa_geodata_data:
  if data["result"]["addressMatches"]:
    pa_geodata.append({
        "city": data["result"]["input"]["address"]["city"],
        "street": data["result"]["input"]["address"]["street"],
        "state": data["result"]["input"]["address"]["state"],
        "x-coordinates": data["result"]["addressMatches"][0]["coordinates"]["x"],
        "y-coordinates": data["result"]["addressMatches"][0]["coordinates"]["y"],
        "tract": data["result"]["addressMatches"][0]["geographies"]["Census Block Groups"][0]["TRACT"]
    })

# %%
pa_geodata_df = pd.DataFrame(pa_geodata)

# %%
pa_geodata_df
# Out:
#              city                    street state  x-coordinates  \
# 0      DOYLESTOWN         595 WEST STATE ST    PA     -75.145568
# 1    PHILADELPHIA            2601 HOLME AVE    PA     -75.042753
# 2    PHILADELPHIA      51 NORTH 39TH STREET    PA     -75.199470
# 3    PHILADELPHIA         800 SPRUCE STREET    PA     -75.154846
# 4      PITTSBURGH      1000 BOWER HILL ROAD    PA     -80.065128
# ..            ...                       ...   ...            ...
# 75        INDIANA         835 HOSPITAL ROAD    PA     -79.158899
# 76     GREENVILLE     110 NORTH MAIN STREET    PA     -80.372424
# 77   WEST CHESTER  701 EAST MARSHALL STREET    PA     -75.601360
# 78  CONNELLSVILLE    401 EAST MURPHY AVENUE    PA     -79.587292
# 79   PUNXSUTAWNEY        81 HILLCREST DRIVE    PA     -78.999979
#
#     y-coordinates   tract
# 0       40.303887  104604
# 1       40.058339  033300
# 2       39.957217  009100
# 3       39.945680  001102
# 4       40.378035  473602
# ..            ...     ...
# 75      40.608085  960800
# 76      41.411157  032200
# 77      39.970485  302702
# 78      40.023126  260800
# 79      40.960236  951100
#
# [80 rows x 6 columns]

# %%
census_and_geodata_df = census_df.merge(pa_geodata_df, on="tract")

# %%
census_and_geodata_df
# Out:
#     median_income poverty_percentage   tract        city  \
# 0           31250               61.7  040200  PITTSBURGH
# 1           28444               55.5  040900  PITTSBURGH
# 2           62857               13.7  080900  PITTSBURGH
# 3           62857               13.7  080900  PITTSBURGH
# 4           79312                6.5  413500  PITTSBURGH
# ..            ...                ...     ...         ...
# 184         77243                9.3  021100    SOMERSET
# 185         59827               15.4  021600  MEYERSDALE
# 186        103966                3.3  022701        YORK
# 187         98322                3.1  022801        YORK
# 188         83115               11.3  023400  HARRISBURG
#
#                       street state  x-coordinates  y-coordinates
# 0         200 LOTHROP STREET    PA     -79.960750      40.441896
# 1          300 HALKET STREET    PA     -79.960326      40.437641
# 2           5324 PENN AVENUE    PA     -79.938034      40.464535
# 3     4800 FRIENDSHIP AVENUE    PA     -79.946781      40.462390
# 4     9100 BABCOCK BOULEVARD    PA     -80.016357      40.574480
# ..                       ...   ...            ...            ...
# 184  225 SOUTH CENTER AVENUE    PA     -79.078548      40.007260
# 185       200 HOSPITAL DRIVE    PA     -79.025064      39.809532
# 186         55 MONUMENT ROAD    PA     -76.717843      39.922946
# 187      1861 POWDER MILL RD    PA     -76.696721      39.916667
# 188  409 SOUTH SECOND STREET    PA     -76.832036      40.229938
#
# [189 rows x 8 columns]

# %%
final_df = (
    cms_transformed_df
    .rename(columns={"address": "street"})
    .merge(
        census_and_geodata_df,
        on=["street", "city", "state"]
    )
)

# %%
final_df
# Out:
#     facility_id                     facility_name                street  \
# 0        390203               DOYLESTOWN HOSPITAL     595 WEST STATE ST
# 1        390204                 NAZARETH HOSPITAL        2601 HOLME AVE
# 2        390204                 NAZARETH HOSPITAL        2601 HOLME AVE
# 3        390223  PENN PRESBYTERIAN MEDICAL CENTER  51 NORTH 39TH STREET
# 4        390223  PENN PRESBYTERIAN MEDICAL CENTER  51 NORTH 39TH STREET
# ..          ...                               ...                   ...
# 184      390199        PUNXSUTAWNEY AREA HOSPITAL    81 HILLCREST DRIVE
# 185      390199        PUNXSUTAWNEY AREA HOSPITAL    81 HILLCREST DRIVE
# 186      390199        PUNXSUTAWNEY AREA HOSPITAL    81 HILLCREST DRIVE
# 187      390199        PUNXSUTAWNEY AREA HOSPITAL    81 HILLCREST DRIVE
# 188      390199        PUNXSUTAWNEY AREA HOSPITAL    81 HILLCREST DRIVE
#
#              city state  zip_code        county telephone_number  start_date  \
# 0      DOYLESTOWN    PA     18901         BUCKS   (215) 345-2200  01/01/2024
# 1    PHILADELPHIA    PA     19152  PHILADELPHIA   (215) 335-6000  01/01/2024
# 2    PHILADELPHIA    PA     19152  PHILADELPHIA   (215) 335-6000  01/01/2024
# 3    PHILADELPHIA    PA     19104  PHILADELPHIA   (215) 662-8000  01/01/2024
# 4    PHILADELPHIA    PA     19104  PHILADELPHIA   (215) 662-8000  01/01/2024
# ..            ...   ...       ...           ...              ...         ...
# 184  PUNXSUTAWNEY    PA     15767     JEFFERSON   (814) 938-1800  01/01/2024
# 185  PUNXSUTAWNEY    PA     15767     JEFFERSON   (814) 938-1800  01/01/2024
# 186  PUNXSUTAWNEY    PA     15767     JEFFERSON   (814) 938-1800  01/01/2024
# 187  PUNXSUTAWNEY    PA     15767     JEFFERSON   (814) 938-1800  01/01/2024
# 188  PUNXSUTAWNEY    PA     15767     JEFFERSON   (814) 938-1800  01/01/2024
#
#        end_date  ...  ssi_colon_lcl ssi_colon_procedures ssi_colon_observed  \
# 0    12/31/2024  ...          0.288                  183                  4
# 1    12/31/2024  ...  Not Available                   25                  0
# 2    12/31/2024  ...  Not Available                   25                  0
# 3    12/31/2024  ...          0.399                  250                  7
# 4    12/31/2024  ...          0.399                  250                  7
# ..          ...  ...            ...                  ...                ...
# 184  12/31/2024  ...  Not Available                   12                  0
# 185  12/31/2024  ...  Not Available                   12                  0
# 186  12/31/2024  ...  Not Available                   12                  0
# 187  12/31/2024  ...  Not Available                   12                  0
# 188  12/31/2024  ...  Not Available                   12                  0
#
#     ssi_colon_predicted  ssi_colon_ucl median_income poverty_percentage  \
# 0                 4.413          2.186        111151                3.1
# 1                 0.689  Not Available         42895               25.7
# 2                 0.689  Not Available         55389               17.3
# 3                 7.682          1.802         73797                6.6
# 4                 7.682          1.802         35139               40.5
# ..                  ...            ...           ...                ...
# 184               0.287  Not Available         53996               23.5
# 185               0.287  Not Available         74250               12.3
# 186               0.287  Not Available         60424               12.2
# 187               0.287  Not Available         71202                8.1
# 188               0.287  Not Available         56310               13.0
#
#       tract x-coordinates y-coordinates
# 0    104604    -75.145568     40.303887
# 1    033300    -75.042753     40.058339
# 2    033300    -75.042753     40.058339
# 3    009100    -75.199470     39.957217
# 4    009100    -75.199470     39.957217
# ..      ...           ...           ...
# 184  951100    -78.999979     40.960236
# 185  951100    -78.999979     40.960236
# 186  951100    -78.999979     40.960236
# 187  951100    -78.999979     40.960236
# 188  951100    -78.999979     40.960236
#
# [189 rows x 51 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 51 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   facility_id           189 non-null    object
#  1   facility_name         189 non-null    object
#  2   street                189 non-null    object
#  3   city                  189 non-null    object
#  4   state                 189 non-null    object
#  5   zip_code              189 non-null    int64
#  6   county                189 non-null    object
#  7   telephone_number      189 non-null    object
#  8   start_date            189 non-null    object
#  9   end_date              189 non-null    object
#  10  cauti_sir             189 non-null    object
#  11  cauti_lcl             189 non-null    object
#  12  cauti_catheter_days   189 non-null    object
#  13  cauti_observed        189 non-null    object
#  14  cauti_predicted       189 non-null    object
#  15  cauti_ucl             189 non-null    object
#  16  clabsi_sir            189 non-null    object
#  17  clabsi_lcl            189 non-null    object
#  18  clabsi_observed       189 non-null    object
#  19  clabsi_predicted      189 non-null    object
#  20  clabsi_ucl            189 non-null    object
#  21  clabsi_device_days    189 non-null    object
#  22  cdiff_sir             189 non-null    object
#  23  cdiff_lcl             189 non-null    object
#  24  cdiff_observed        189 non-null    object
#  25  cdiff_patient_days    189 non-null    object
#  26  cdiff_predicted       189 non-null    object
#  27  cdiff_ucl             189 non-null    object
#  28  mrsa_sir              189 non-null    object
#  29  mrsa_lcl              189 non-null    object
#  30  mrsa_observed         189 non-null    object
#  31  mrsa_patient_days     189 non-null    object
#  32  mrsa_predicted        189 non-null    object
#  33  mrsa_ucl              189 non-null    object
#  34  ssi_hyst_sir          189 non-null    object
#  35  ssi_hyst_lcl          189 non-null    object
#  36  ssi_hyst_procedures   189 non-null    object
#  37  ssi_hyst_observed     189 non-null    object
#  38  ssi_hyst_predicted    189 non-null    object
#  39  ssi_hyst_ucl          189 non-null    object
#  40  ssi_colon_sir         189 non-null    object
#  41  ssi_colon_lcl         189 non-null    object
#  42  ssi_colon_procedures  189 non-null    object
#  43  ssi_colon_observed    189 non-null    object
#  44  ssi_colon_predicted   189 non-null    object
#  45  ssi_colon_ucl         189 non-null    object
#  46  median_income         189 non-null    object
#  47  poverty_percentage    189 non-null    object
#  48  tract                 189 non-null    object
#  49  x-coordinates         189 non-null    float64
#  50  y-coordinates         189 non-null    float64
# dtypes: float64(2), int64(1), object(48)
# memory usage: 75.4+ KB

# %%
final_df
# Out:
#      Facility ID                       Facility Name               Address  \
# 0         390001  GEISINGER-COMMUNITY MEDICAL CENTER  1822 MULBERRY STREET
# 1         390001  GEISINGER-COMMUNITY MEDICAL CENTER  1822 MULBERRY STREET
# 2         390001  GEISINGER-COMMUNITY MEDICAL CENTER  1822 MULBERRY STREET
# 3         390001  GEISINGER-COMMUNITY MEDICAL CENTER  1822 MULBERRY STREET
# 4         390001  GEISINGER-COMMUNITY MEDICAL CENTER  1822 MULBERRY STREET
# ...          ...                                 ...                   ...
# 8518      391316                      UPMC WELLSBORO  32-36 CENTRAL AVENUE
# 8519      391316                      UPMC WELLSBORO  32-36 CENTRAL AVENUE
# 8520      391316                      UPMC WELLSBORO  32-36 CENTRAL AVENUE
# 8521      391316                      UPMC WELLSBORO  32-36 CENTRAL AVENUE
# 8522      391316                      UPMC WELLSBORO  32-36 CENTRAL AVENUE
#
#       City/Town State  ZIP Code County/Parish Telephone Number     Measure ID  \
# 0      SCRANTON    PA     18510    LACKAWANNA   (570) 703-8000  HAI_1_CILOWER
# 1      SCRANTON    PA     18510    LACKAWANNA   (570) 703-8000  HAI_1_CILOWER
# 2      SCRANTON    PA     18510    LACKAWANNA   (570) 703-8000  HAI_1_CIUPPER
# 3      SCRANTON    PA     18510    LACKAWANNA   (570) 703-8000  HAI_1_CIUPPER
# 4      SCRANTON    PA     18510    LACKAWANNA   (570) 703-8000     HAI_1_DOPC
# ...         ...   ...       ...           ...              ...            ...
# 8518  WELLSBORO    PA     16901         TIOGA   (570) 723-7764      HAI_6_SIR
# 8519  WELLSBORO    PA     16901         TIOGA   (570) 723-7764      HAI_6_SIR
# 8520  WELLSBORO    PA     16901         TIOGA   (570) 723-7764      HAI_6_SIR
# 8521  WELLSBORO    PA     16901         TIOGA   (570) 723-7764      HAI_6_SIR
# 8522  WELLSBORO    PA     16901         TIOGA   (570) 723-7764      HAI_6_SIR
#
#                                            Measure Name  ... S1901_C01_012E  \
# 0     Central Line Associated Bloodstream Infection ...  ...          68929
# 1     Central Line Associated Bloodstream Infection ...  ...          55278
# 2     Central Line Associated Bloodstream Infection ...  ...          68929
# 3     Central Line Associated Bloodstream Infection ...  ...          55278
# 4     Central Line Associated Bloodstream Infection:...  ...          68929
# ...                                                 ...  ...            ...
# 8518                     Clostridium Difficile (C.Diff)  ...          71049
# 8519                     Clostridium Difficile (C.Diff)  ...          71518
# 8520                     Clostridium Difficile (C.Diff)  ...          67000
# 8521                     Clostridium Difficile (C.Diff)  ...          58407
# 8522                     Clostridium Difficile (C.Diff)  ...          64297
#
#       S1701_C03_001E county   tract       city                street state  \
# 0               10.7    013  100400   SCRANTON  1822 MULBERRY STREET    PA
# 1               27.6    069  100400   SCRANTON  1822 MULBERRY STREET    PA
# 2               10.7    013  100400   SCRANTON  1822 MULBERRY STREET    PA
# 3               27.6    069  100400   SCRANTON  1822 MULBERRY STREET    PA
# 4               10.7    013  100400   SCRANTON  1822 MULBERRY STREET    PA
# ...              ...    ...     ...        ...                   ...   ...
# 8518            10.4    005  950800  WELLSBORO  32-36 CENTRAL AVENUE    PA
# 8519             7.0    015  950800  WELLSBORO  32-36 CENTRAL AVENUE    PA
# 8520            10.6    061  950800  WELLSBORO  32-36 CENTRAL AVENUE    PA
# 8521            15.0    065  950800  WELLSBORO  32-36 CENTRAL AVENUE    PA
# 8522            10.1    117  950800  WELLSBORO  32-36 CENTRAL AVENUE    PA
#
#      x-coordinates y-coordinates zip_code
# 0       -75.646323     41.400927    18510
# 1       -75.646323     41.400927    18510
# 2       -75.646323     41.400927    18510
# 3       -75.646323     41.400927    18510
# 4       -75.646323     41.400927    18510
# ...            ...           ...      ...
# 8518    -77.300508     41.746249    16901
# 8519    -77.300508     41.746249    16901
# 8520    -77.300508     41.746249    16901
# 8521    -77.300508     41.746249    16901
# 8522    -77.300508     41.746249    16901
#
# [8523 rows x 25 columns]

# %%
final_df.to_csv("final.csv", index=False)
